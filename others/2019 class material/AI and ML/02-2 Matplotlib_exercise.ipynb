# %% [markdown]
# ## Matplotlib练习

# %% [markdown]
# ### 1. 用蓝线绘制函数𝑓(𝑥) = 𝑥^2−2𝑥+3的图表，并在坐标(1,2)位置处标上一个红色的点

# %%
import matplotlib.pyplot as plt
import numpy as np
def f(x):
    result = x * x - 2 * x + 3
    return result
x_list = np.linspace(0,5,num = 100)
# print(x_list)
y = []
for x_item in x_list:
    y.append(f(x_item))
plt.plot(x_list,y,"blue",0,2,"red")
plt.scatter(1,2,c="red")
plt.show()

# %% [markdown]
# ### 2. 使用np.linspace()函数生成t∈[0, 2𝜋]。给定𝑥=16*sin⁡(𝑡)^3和𝑦=13*cos⁡(𝑡)−5*cos⁡(2𝑡)−2*cos⁡(3𝑡)−cos⁡(4𝑡)，画出x-y图表，并给图标添加一个题目：Heart

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
def function_x(t):
    result = 16 * (math.sin(t))**3
    return result
def function_y(t):
    result = 13 * math.cos(t) - 5 * math.cos(2*t) - 2 * math.cos(3*t) - math.cos(4*t)
    return result
t_list = np.linspace(0,2*math.pi,num = 1000)
x = []
y = []
for t_item in t_list:
    x.append(function_x(t_item))
    y.append(function_y(t_item))
plt.plot(x,y)
plt.title("X and Y")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
